# %% [markdown]
# # Data Science Tools and Ecosytem

# %% [markdown]
# ## INTRODUCTION
#
# This notebook provides an overview of tools and technologies used in Data Science.

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. Julia
# 4. SQL

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. Numpy
# 2. Pandas
# 3. Tensorflow
# 4. Matplotlib
# 5. Skicit-learn

# %% [markdown]
# # Data Science Tools

# %% [markdown]
# |Data Science Tools|
# |--------------------|
# |Jupyter Notebook|
# |Github|
# |Rstudio|

# %% [markdown]
# # Arithematic expression examples:
# ### Below are a few examples of evaluating arithematic expressions in Python.

# %%
x = 12
y = 46
x/y

# %%
# This a simple arithmetic expression to multiply then add integers
(3*4)+5

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes/60
hours

# %% [markdown]
# **Objectives:**

# %% [markdown]
# - Tools used by Data Scientist
# - Libraries used
# - Popular Languages
# - Perform basic arithematic operations
# - Convert minutes to hours

# %% [markdown]
# ## Author

# %% [markdown]
# Bhavika Gupta
